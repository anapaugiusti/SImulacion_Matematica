# %%
# %matplotlib inline

import matplotlib.pylab as plt
import numpy as np
from sympy import *
import pandas as pd
from scipy import stats
from scipy.integrate import quad

# %%
init_printing()

# %% [markdown]
# $$ y = \int_{a}^{b} f(x)dx.$$

# %% [markdown]
# Ejercicio:  $$ f(x) = sen(x), (0, \pi) $$

# %%
t =np.arange(0,np.pi,0.1)
f =lambda x: np.sin(x)
y = f(t)

plt.plot(t,y)

# %%
quad(f,0,np.pi)
# Out:
# (2.0, 2.220446049250313e-14)

# %% [markdown]
# Integración simbolica

# %%
var("X,t")

plot(sin(X),(X,0,pi))

# %%
A_ = sin(X) + diff (X**2)+integrate(X**2)
A_
# Out:
#  3
# X
# ── + 2⋅X + sin(X)
# 3

# %%
A_.subs(X,10)
# Out:
# sin(10) + 1060/3

# %%
N(A_.subs(X,10))
# Out:
# 352.789312222444

# %%
integrate(sin(X),(X,0,pi))
# Out:
# 2

# %% [markdown]
# # INTEGRACIÓN POR MONTE CARLO

# %%
Num= 100
f = lambda x:np.sin(x)
a,b =0, np.pi
Altura=1

#puntos aleatorios
x= np.random.uniform(a,b,Num)
y= np.random.uniform(a,Altura,Num)

#punto para grafica
x_graf = np.arange(a,b,0.1)
fx=f(x)

plt.plot(x[y>fx],y[y>fx],"go")
plt.plot(x[y<fx],y[y<fx],"ro")
plt.plot(x_graf,f(x_graf))

N_0 = len(x[y<fx])
base =b-a
yest = N_0/Num*(base*Altura)
print(yest)
# Out:
# 1.853539665617978

# %% [markdown]
# Segundo Ejercicio

# %% [markdown]
# $$ f(x) = -x^2 +10 $$

# %%
t =np.arange(0,np.pi,0.1)
f =lambda x: -x**2 + 10
y = f(t)

plt.plot(t,y)

# %%
quad(f,0,1)
# Out:
# (9.666666666666666, 1.0732155904709846e-13)

# %%
var("X,t")

plot(-X**2 + 10),(X,0,1))
# Out:
#   File "<ipython-input-43-67e0426e4b5e>", line 3
#     plot(-X**2 + 10),(X,0,1))
#                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ......

# %% [markdown]
# Ejercicio: $$ y = x , y=x^2, en [0,1] $$

# %%
plt.fill_between?

# %%
x = np.linspace(-0.1,1.1)
y = x**2

plt.plot(x,x,"k--",label="$y=x")
plt.plot(x,y,"k",label="$y=x^2")
plt.fill_between(x,x,y)

# %%
Num= 1000000
f = lambda x:x-x**2
a,b =0, 1
Altura=1

#puntos aleatorios
x= np.random.uniform(a,b,Num)
y= np.random.uniform(a,Altura,Num)

#punto para grafica
x_graf = np.arange(a,b,0.1)
fx=f(x)

N_0 = len(x[y<fx])
base =b-a
yest = N_0/Num*(base*Altura)
print(yest)
# Out:
# 0.166394

# %%
quad(f,0,1)
# Out:
# (0.16666666666666666, 1.850371707708594e-15)

# %% [markdown]
# $$ Tarea $$
